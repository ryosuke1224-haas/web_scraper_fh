# %%
cd C:\Users\ryosu\OneDrive\デスクトップ\Peek\hh-scraper
# Out:
# C:\Users\ryosu\OneDrive\デスクトップ\Peek\hh-scraper

# %%
import requests
import time
import pandas as pd
import csv
from selenium import webdriver
from urllib.parse import urljoin
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import requests
import re
import bs4

# %%
links=pd.read_csv('links_findahaunt.csv',header=None)

# %%
links
# Out:
#                                            0
# 0    https://www.findahaunt.com/single/14936
# 1    https://www.findahaunt.com/single/10677
# 2    https://www.findahaunt.com/single/10675
# 3    https://www.findahaunt.com/single/18988
# 4    https://www.findahaunt.com/single/17887
# ..                                       ...
# 168  https://www.findahaunt.com/single/13957
# 169  https://www.findahaunt.com/single/15393
# 170  https://www.findahaunt.com/single/11332
# 171  https://www.findahaunt.com/single/17017
# 172  https://www.findahaunt.com/single/18035
#
# [173 rows x 1 columns]

# %%
for i in links[0]:
    print(i)
# Out:
# https://www.findahaunt.com/single/14936
# https://www.findahaunt.com/single/10677
# https://www.findahaunt.com/single/10675
# https://www.findahaunt.com/single/18988
# https://www.findahaunt.com/single/17887
# https://www.findahaunt.com/single/10426
# https://www.findahaunt.com/single/10674
# https://www.findahaunt.com/single/13655
# https://www.findahaunt.com/single/11556
# https://www.findahaunt.com/single/12887
# https://www.findahaunt.com/single/18281
# https://www.findahaunt.com/single/11557
# https://www.findahaunt.com/single/14989
# https://www.findahaunt.com/single/17126
# https://www.findahaunt.com/single/14956
# https://www.findahaunt.com/single/12473
# https://www.findahaunt.com/single/15657
# https://www.findahaunt.com/single/15661
# https://www.findahaunt.com/single/13950
# https://www.findahaunt.com/single/13949
# https://www.findahaunt.com/single/12885
# https://www.findahaunt.com/single/14155
# https://www.findahaunt.com/single/14971
# https://www.findahaunt.com/single/14972
# https://www.findahaunt.com/single/14973
# https://www.findahaunt.com/single/14990
# https://www.findahaunt.com/single/14991
# https://www.findahaunt.com/single/14153
# https://www.findahaunt.com/single/14945
# https://www.findahaunt.com/single/18253
# https://www.findahaunt.com/single/17163
# https://www.findahaunt.com/single/14957
# https://www.findahaunt.com/single/16296
# https://www.findahaunt.com/single/14974
# https://www.findahaunt.com/single/14975
# https://www.findahaunt.com/single/16178
# https://www.findahaunt.com/single/17129
# https://www.findahaunt.com/single/15672
# https://www.findahaunt.com/single/17069
# https://www.findahaunt.com/single/13952
# https://www.findahaunt.com/single/10679
# https://www.findahaunt.com/single/17822
# https://www.findahaunt.com/single/10661
# https://www.findahaunt.com/single/13948
# https://www.findahaunt.com/single/14984
# https://www.findahaunt.com/single/13168
# https://www.findahaunt.com/single/13166
# https://www.findahaunt.com/single/15711
# https://www.findahaunt.com/single/18738
# https://www.findahaunt.com/single/13167
# https://www.findahaunt.com/single/15769
# https://www.findahaunt.com/single/14968
# https://www.findahaunt.com/single/10195
# https://www.findahaunt.com/single/18917
# https://www.findahaunt.com/single/12539
# https://www.findahaunt.com/single/10262
# https://www.findahaunt.com/single/10712
# https://www.findahaunt.com/single/10266
# https://www.findahaunt.com/single/10133
# https://www.findahaunt.com/single/14643
# https://www.findahaunt.com/single/10352
# https://www.findahaunt.com/single/18709
# https://www.findahaunt.com/single/12029
# https://www.findahaunt.com/single/12834
# https://www.findahaunt.com/single/11035
# https://www.findahaunt.com/single/10142
# https://www.findahaunt.com/single/17933
# https://www.findahaunt.com/single/10846
# https://www.findahaunt.com/single/10485
# https://www.findahaunt.com/single/13559
# https://www.findahaunt.com/single/18930
# https://www.findahaunt.com/single/13414
# https://www.findahaunt.com/single/10366
# https://www.findahaunt.com/single/11979
# https://www.findahaunt.com/single/10271
# https://www.findahaunt.com/single/10408
# https://www.findahaunt.com/single/10647
# https://www.findahaunt.com/single/11501
# https://www.findahaunt.com/single/18898
# https://www.findahaunt.com/single/18158
# https://www.findahaunt.com/single/10226
# https://www.findahaunt.com/single/11018
# https://www.findahaunt.com/single/10439
# https://www.findahaunt.com/single/14040
# https://www.findahaunt.com/single/11139
# https://www.findahaunt.com/single/10264
# https://www.findahaunt.com/single/11136
# https://www.findahaunt.com/single/12601
# https://www.findahaunt.com/single/18250
# https://www.findahaunt.com/single/10440
# https://www.findahaunt.com/single/11142
# https://www.findahaunt.com/single/11553
# https://www.findahaunt.com/single/10932
# https://www.findahaunt.com/single/13600
# https://www.findahaunt.com/single/11554
# https://www.findahaunt.com/single/10238
# https://www.findahaunt.com/single/15991
# https://www.findahaunt.com/single/10473
# https://www.findahaunt.com/single/17874
# https://www.findahaunt.com/single/12876
# https://www.findahaunt.com/single/10783
# https://www.findahaunt.com/single/12725
# https://www.findahaunt.com/single/18701
# https://www.findahaunt.com/single/12375
# https://www.findahaunt.com/single/11241
# https://www.findahaunt.com/single/13923
# https://www.findahaunt.com/single/10709
# https://www.findahaunt.com/single/18474
# https://www.findahaunt.com/single/15985
# https://www.findahaunt.com/single/16108
# https://www.findahaunt.com/single/12306
# https://www.findahaunt.com/single/11716
# https://www.findahaunt.com/single/14954
# https://www.findahaunt.com/single/10192
# https://www.findahaunt.com/single/10323
# https://www.findahaunt.com/single/14955
# https://www.findahaunt.com/single/12378
# https://www.findahaunt.com/single/16234
# https://www.findahaunt.com/single/11130
# https://www.findahaunt.com/single/14536
# https://www.findahaunt.com/single/12799
# https://www.findahaunt.com/single/13826
# https://www.findahaunt.com/single/13824
# https://www.findahaunt.com/single/18791
# https://www.findahaunt.com/single/12880
# https://www.findahaunt.com/single/14456
# https://www.findahaunt.com/single/15834
# https://www.findahaunt.com/single/13818
# https://www.findahaunt.com/single/11134
# https://www.findahaunt.com/single/14534
# https://www.findahaunt.com/single/17929
# https://www.findahaunt.com/single/17530
# https://www.findahaunt.com/single/15194
# https://www.findahaunt.com/single/10495
# https://www.findahaunt.com/single/18671
# https://www.findahaunt.com/single/14035
# https://www.findahaunt.com/single/11003
# https://www.findahaunt.com/single/11538
# https://www.findahaunt.com/single/14892
# https://www.findahaunt.com/single/11024
# https://www.findahaunt.com/single/13959
# https://www.findahaunt.com/single/16203
# https://www.findahaunt.com/single/17930
# https://www.findahaunt.com/single/14952
# https://www.findahaunt.com/single/16293
# https://www.findahaunt.com/single/17900
# https://www.findahaunt.com/single/10644
# https://www.findahaunt.com/single/12665
# https://www.findahaunt.com/single/12547
# https://www.findahaunt.com/single/16315
# https://www.findahaunt.com/single/14010
# https://www.findahaunt.com/single/15394
# https://www.findahaunt.com/single/12384
# https://www.findahaunt.com/single/11522
# https://www.findahaunt.com/single/11141
# https://www.findahaunt.com/single/10650
# https://www.findahaunt.com/single/14996
# https://www.findahaunt.com/single/12878
# https://www.findahaunt.com/single/11239
# https://www.findahaunt.com/single/13953
# https://www.findahaunt.com/single/12381
# https://www.findahaunt.com/single/13899
# https://www.findahaunt.com/single/11511
# https://www.findahaunt.com/single/13954
# https://www.findahaunt.com/single/13901
# https://www.findahaunt.com/single/13874
# https://www.findahaunt.com/single/15379
# https://www.findahaunt.com/single/10669
# https://www.findahaunt.com/single/13957
# https://www.findahaunt.com/single/15393
# https://www.findahaunt.com/single/11332
# https://www.findahaunt.com/single/17017
# https://www.findahaunt.com/single/18035

# %%
names=[]
adresses=[]
webs=[]
phones=[]
for i in links[0]:
    try:
        res = requests.get(i)
        individualpage = BeautifulSoup(res.text, 'lxml')
        name = individualpage.find("article",class_="content-listing").find("h1").text
        names.append(name)
        try:
            adress=individualpage.find("article",class_="content-listing").find('p').find("a").text
            adresses.append(adress)
        except:
            adresses.append('cannot find')
        try:
            web=individualpage.find("a",class_="hauntsite").get("href")
            web=web.replace('?utm_source=FindAHaunt.com&utm_medium=website&utm_campaign=HauntedHouseMedia','')
            webs.append(web)
        except:
            webs.append('cannot find')   
        
        try:
            phone=individualpage.find_all(text=re.compile(r'\d\d\d-\d\d\d-\d\d\d\d'))
            phones.append(phone)
        except:
            phones.append('cannot find')
    except:
        pass

# %%
df=pd.DataFrame({"name":names,
    "adress":adresses,
    "website":webs,
    "phone":phones
    
})

# %%
df_new=df.drop_duplicates(["name"])

# %%
df_new.to_csv('output_findahaunt.csv')
